# %%
pip install sodapy

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cdc.gov", None)

results = client.get("n8mc-b4w4",limit=10000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
CA_race = results_df[results_df['state_fips_code']=='06']
CA_race.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
pd.read_csv('https://data.cdc.gov/resource/n8mc-b4w4.csv')
# Out:
#     case_month res_state  ...  death_yn  underlying_conditions_yn
# 0      2020-02       NaN  ...       NaN                       NaN
# 1      2020-02       NaN  ...       NaN                       Yes
# 2      2020-02       NaN  ...       NaN                       Yes
# 3      2020-08       NaN  ...   Missing                       Yes
# 4      2020-08       NaN  ...   Missing                       Yes
# ..         ...       ...  ...       ...                       ...
# 995    2020-12        GA  ...   Missing                       NaN
# 996    2020-12        GA  ...   Missing                       NaN
# 997    2020-12        GA  ...   Missing                       NaN
# 998    2020-12        GA  ...   Missing                       NaN
# 999    2020-12        GA  ...   Missing                       NaN
#
# [1000 rows x 19 columns]
